# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind, chi2_contingency
import rpy2.robjects.numpy2ri
from rpy2.robjects.packages import importr
rpy2.robjects.numpy2ri.activate()
stats = importr('stats')

# %% [markdown]
# # 미션1

# %%
raw_df = pd.read_excel('/content/drive/MyDrive/lsda02/data/customers.xlsx')
raw_df.head()
# Out:
#     CustID     Sex      Race  BirthDate College  HouseholdSize  ZipCode  \
# 0  1530016  Female     Black 1986-12-16     Yes              5    90047
# 1  1531136    Male     White 1993-05-09     Yes              5    90026
# 2  1532160    Male     Black 1966-05-22     Yes              2    90027
# 3  1532307    Male     White 1964-09-16     Yes              4    90029
# 4  1532356  Female  Hispanic 1964-07-15      No              5    90017
#
#    Income  Spending2017  Spending2018  NumOfOrders  DaysSinceLast  \
# 0   53000           287           241            3            101
# 1   94000          1227           843           12            262
# 2   64000           523           719            9            122
# 3   60000           516           582           13            129
# 4   47000           555           845            7             97
#
#         Satisfaction Channel
# 0  Very Dissatisfied      SM
# 1            Neutral      TV
# 2     Very Satisfied      TV
# 3  Very Dissatisfied      SM
# 4  Very Dissatisfied     Web

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         200 non-null    int64
#  1   Sex            200 non-null    object
#  2   Race           200 non-null    object
#  3   BirthDate      200 non-null    datetime64[ns]
#  4   College        200 non-null    object
#  5   HouseholdSize  200 non-null    int64
#  6   ZipCode        200 non-null    int64
#  7   Income         200 non-null    int64
#  8   Spending2017   200 non-null    int64
#  9   Spending2018   200 non-null    int64
#  10  NumOfOrders    200 non-null    int64
#  11  DaysSinceLast  200 non-null    int64
#  12  Satisfaction   200 non-null    object
#  13  Channel        200 non-null    object
# dtypes: datetime64[ns](1), int64(8), object(5)
# memory usage: 22.0+ KB

# %%
# 데이터 전처리할 사본 생성 - 문제가 생기면 원본으로 바로 재생성 가능하게
df = raw_df.copy()
df.head()
# Out:
#     CustID     Sex      Race  BirthDate College  HouseholdSize  ZipCode  \
# 0  1530016  Female     Black 1986-12-16     Yes              5    90047
# 1  1531136    Male     White 1993-05-09     Yes              5    90026
# 2  1532160    Male     Black 1966-05-22     Yes              2    90027
# 3  1532307    Male     White 1964-09-16     Yes              4    90029
# 4  1532356  Female  Hispanic 1964-07-15      No              5    90017
#
#    Income  Spending2017  Spending2018  NumOfOrders  DaysSinceLast  \
# 0   53000           287           241            3            101
# 1   94000          1227           843           12            262
# 2   64000           523           719            9            122
# 3   60000           516           582           13            129
# 4   47000           555           845            7             97
#
#         Satisfaction Channel
# 0  Very Dissatisfied      SM
# 1            Neutral      TV
# 2     Very Satisfied      TV
# 3  Very Dissatisfied      SM
# 4  Very Dissatisfied     Web

# %%
# 대학교를 졸업한 1982년에서 1999년까지 태어난 고객의 데이터를 생성하세요.
df['College'].value_counts()
# Out:
# College
# Yes    168
# No      32
# Name: count, dtype: int64

# %%
print(df.query('College == "Yes"'))
print(df[df['College'] == 'Yes'])
# Out:
#       CustID     Sex             Race  BirthDate College  HouseholdSize  \
# 0    1530016  Female            Black 1986-12-16     Yes              5
# 1    1531136    Male            White 1993-05-09     Yes              5
# 2    1532160    Male            Black 1966-05-22     Yes              2
# 3    1532307    Male            White 1964-09-16     Yes              4
# 5    1532387    Male            White 1957-08-27     Yes              2
# ..       ...     ...              ...        ...     ...            ...
# 195  1578525    Male         Hispanic 1963-12-12     Yes              1
# 196  1579349    Male            Asian 1980-12-19     Yes              1
# 197  1579389  Female  American Indian 2000-05-21     Yes              1
# 198  1579857  Female            White 1991-01-26     Yes              1
# 199  1579979    Male            White 1999-07-05     Yes              5
#
#      ZipCode  Income  Spending2017  Spending2018  NumOfOrders  DaysSinceLast  \
# 0      90047   53000           287           241            3            101
# 1      90026   94000          1227           843           12            262
# 2      90027   64000           523           719            9            122
# 3      90029   60000           516           582           13            129
# 5      90028   67000           631           452            9            150
# ..       ...     ...           ...           ...          ...            ...
# 195    90005   82000          1521          1121           25            302
# 196    90010   49000           217           397           10            200
# 197    90009   50000           625           514           10            233
# 198    90055   52000           325           586           13            219
# 199    90043  102000          1080           926           10            113
#
#               Satisfaction   Channel
# 0        Very Dissatisfied        SM
# 1                  Neutral        TV
# 2           Very Satisfied        TV
# 3        Very Dissatisfied        SM
# 5                  Neutral        SM
# ..                     ...       ...
# 195     Somewhat Satisfied       Web
# 196     Somewhat Satisfied       Web
# 197  Somewhat Dissatisfied  Referral
# 198  Somewhat Dissatisfied  Referral
# 199     Somewhat Satisfied        SM
#
# [168 rows x 14 columns]
#       CustID     Sex             Race  BirthDate College  HouseholdSize  \
# 0    1530016  Female            Black 1986-12-16     Yes              5
# 1    1531136    Male            White 1993-05-09     Yes              5
# 2    1532160    Male            Black 1966-05-22     Yes              2
# 3    1532307    Male            White 1964-09-16     Yes              4
# 5    1532387    Male            White 1957-08-27     Yes              2
# ..       ...     ...              ...        ...     ...            ...
# 195  1578525    Male         Hispanic 1963-12-12     Yes              1
# 196  1579349    Male            Asian 1980-12-19     Yes              1
# 197  1579389  Female  American Indian 2000-05-21     Yes              1
# 198  1579857  Female            White 1991-01-26     Yes              1
# 199  1579979    Male            White 1999-07-05     Yes              5
#
#      ZipCode  Income  Spending2017  Spending2018  NumOfOrders  DaysSinceLast  \
# 0      90047   53000           287           241            3            101
# 1      90026   94000          1227           843           12            262
# 2      90027   64000           523           719            9            122
# 3      90029   60000           516           582           13            129
# 5      90028   67000           631           452            9            150
# ..       ...     ...           ...           ...          ...            ...
# 195    90005   82000          1521          1121           25            302
# 196    90010   49000           217           397           10            200
# 197    90009   50000           625           514           10            233
# 198    90055   52000           325           586           13            219
# 199    90043  102000          1080           926           10            113
#
#               Satisfaction   Channel
# 0        Very Dissatisfied        SM
# 1                  Neutral        TV
# 2           Very Satisfied        TV
# 3        Very Dissatisfied        SM
# 5                  Neutral        SM
# ..                     ...       ...
# 195     Somewhat Satisfied       Web
# 196     Somewhat Satisfied       Web
# 197  Somewhat Dissatisfied  Referral
# 198  Somewhat Dissatisfied  Referral
# 199     Somewhat Satisfied        SM
#
# [168 rows x 14 columns]

# %%
# 대학교 졸업한 사람
college = df[df['College'] == 'Yes']
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 168 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         168 non-null    int64
#  1   Sex            168 non-null    object
#  2   Race           168 non-null    object
#  3   BirthDate      168 non-null    datetime64[ns]
#  4   College        168 non-null    object
#  5   HouseholdSize  168 non-null    int64
#  6   ZipCode        168 non-null    int64
#  7   Income         168 non-null    int64
#  8   Spending2017   168 non-null    int64
#  9   Spending2018   168 non-null    int64
#  10  NumOfOrders    168 non-null    int64
#  11  DaysSinceLast  168 non-null    int64
#  12  Satisfaction   168 non-null    object
#  13  Channel        168 non-null    object
# dtypes: datetime64[ns](1), int64(8), object(5)
# memory usage: 19.7+ KB

# %%
# 1982~1999년 출생한 고객을 추출하기 위한 타임스탬프 생성
start_date = pd.to_datetime("1982-01-01")
start_date
# Out:
# Timestamp('1982-01-01 00:00:00')

# %%
end_date = pd.to_datetime("1999-12-31")
end_date
# Out:
# Timestamp('1999-12-31 00:00:00')

# %%
# 데이터[(조건1) & (조건2)]
college_8299 = college[(college['BirthDate'] >= start_date) & (college['BirthDate'] <= end_date)]
college_8299.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         59 non-null     int64
#  1   Sex            59 non-null     object
#  2   Race           59 non-null     object
#  3   BirthDate      59 non-null     datetime64[ns]
#  4   College        59 non-null     object
#  5   HouseholdSize  59 non-null     int64
#  6   ZipCode        59 non-null     int64
#  7   Income         59 non-null     int64
#  8   Spending2017   59 non-null     int64
#  9   Spending2018   59 non-null     int64
#  10  NumOfOrders    59 non-null     int64
#  11  DaysSinceLast  59 non-null     int64
#  12  Satisfaction   59 non-null     object
#  13  Channel        59 non-null     object
# dtypes: datetime64[ns](1), int64(8), object(5)
# memory usage: 6.9+ KB

# %%
# 한번에 만들어보자!
df = raw_df.copy()
start_date = pd.to_datetime("1982-01-01")
end_date = pd.to_datetime("1999-12-31")
college_8299 = df[(df['College'] == 'Yes') & (df['BirthDate'] >= start_date) & (df['BirthDate'] <= end_date)]
college_8299.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         59 non-null     int64
#  1   Sex            59 non-null     object
#  2   Race           59 non-null     object
#  3   BirthDate      59 non-null     datetime64[ns]
#  4   College        59 non-null     object
#  5   HouseholdSize  59 non-null     int64
#  6   ZipCode        59 non-null     int64
#  7   Income         59 non-null     int64
#  8   Spending2017   59 non-null     int64
#  9   Spending2018   59 non-null     int64
#  10  NumOfOrders    59 non-null     int64
#  11  DaysSinceLast  59 non-null     int64
#  12  Satisfaction   59 non-null     object
#  13  Channel        59 non-null     object
# dtypes: datetime64[ns](1), int64(8), object(5)
# memory usage: 6.9+ KB

# %%
# 여성
female = college_8299[college_8299['Sex'] == "Female"]
female.info()
female.to_csv("/content/drive/MyDrive/lsda02/data/female.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         21 non-null     int64
#  1   Sex            21 non-null     object
#  2   Race           21 non-null     object
#  3   BirthDate      21 non-null     datetime64[ns]
#  4   College        21 non-null     object
#  5   HouseholdSize  21 non-null     int64
#  6   ZipCode        21 non-null     int64
#  7   Income         21 non-null     int64
#  8   Spending2017   21 non-null     int64
#  9   Spending2018   21 non-null     int64
#  10  NumOfOrders    21 non-null     int64
#  11  DaysSinceLast  21 non-null     int64
#  12  Satisfaction   21 non-null     object
#  13  Channel        21 non-null     object
# dtypes: datetime64[ns](1), int64(8), object(5)
# memory usage: 2.5+ KB

# %%
# 남성
male = college_8299[college_8299['Sex'] == "Male"]
male.info()
male.to_csv("/content/drive/MyDrive/lsda02/data/male.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, 1 to 199
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         38 non-null     int64
#  1   Sex            38 non-null     object
#  2   Race           38 non-null     object
#  3   BirthDate      38 non-null     datetime64[ns]
#  4   College        38 non-null     object
#  5   HouseholdSize  38 non-null     int64
#  6   ZipCode        38 non-null     int64
#  7   Income         38 non-null     int64
#  8   Spending2017   38 non-null     int64
#  9   Spending2018   38 non-null     int64
#  10  NumOfOrders    38 non-null     int64
#  11  DaysSinceLast  38 non-null     int64
#  12  Satisfaction   38 non-null     object
#  13  Channel        38 non-null     object
# dtypes: datetime64[ns](1), int64(8), object(5)
# memory usage: 4.5+ KB

# %%
# 한번에 해보자!
# 그룹 객체 => groupby(그룹화에 사용할 열)
college_8299_grouped_sex = college_8299.groupby(by = 'Sex')
college_8299_grouped_sex.get_group('Female').to_csv("/content/drive/MyDrive/lsda02/data/female.csv")
college_8299_grouped_sex.get_group('Male').to_csv("/content/drive/MyDrive/lsda02/data/male.csv")

# %% [markdown]
# # 미션2

# %%
# 미션 1에서 만든 대학교 졸업한 82년~99년 출생 고객의 데이터를 이용
# Sex, Race, HouseholdSize, Income, Satisfaction, Channel 변수를 선택하여 desc_df로 저장
selected_columns = ['Sex', 'Race', 'HouseholdSize', 'Income', 'Satisfaction', 'Channel']
desc_df = college_8299[selected_columns]
desc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sex            59 non-null     object
#  1   Race           59 non-null     object
#  2   HouseholdSize  59 non-null     int64
#  3   Income         59 non-null     int64
#  4   Satisfaction   59 non-null     object
#  5   Channel        59 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 3.2+ KB

# %%
# desc_df를 이용하여 남녀 차이를 보기 위한 기술통계표를 작성하세요.
print(pd.crosstab(desc_df.Race, desc_df.Sex))
print("\n")
print(pd.crosstab(desc_df.HouseholdSize, desc_df.Sex))
print("\n")
print("Female: ", pd.DataFrame(desc_df[desc_df.Sex == "Female"].Income.describe().loc[["mean", "std"]]).T)
print("Male: ", pd.DataFrame(desc_df[desc_df.Sex == "Male"].Income.describe().loc[["mean", "std"]]).T)
print("\n")
print(pd.crosstab(desc_df.Satisfaction, desc_df.Sex))
print("\n")
print(pd.crosstab(desc_df.Channel, desc_df.Sex))
# Out:
# Sex               Female  Male
# Race
# American Indian        0     2
# Asian                  0     4
# Black                  7     6
# Hispanic               4     8
# Pacific Islander       0     1
# White                 10    17
#
#
# Sex            Female  Male
# HouseholdSize
# 1                   4     6
# 2                   4     7
# 3                   5     9
# 4                   2     8
# 5                   6     8
#
#
# Female:                  mean           std
# Income  61285.714286  19680.301972
# Male:                  mean          std
# Income  83157.894737  27514.64113
#
#
# Sex                    Female  Male
# Satisfaction
# Neutral                     1     6
# Somewhat Dissatisfied       3     3
# Somewhat Satisfied         11    21
# Very Dissatisfied           2     2
# Very Satisfied              4     6
#
#
# Sex       Female  Male
# Channel
# Referral       6     6
# SM             3    16
# TV             4     9
# Web            8     7

# %%
desc_df.Income.describe()
# Out:
# count        59.000000
# mean      75372.881356
# std       26982.688131
# min       34000.000000
# 25%       55000.000000
# 50%       69000.000000
# 75%       94000.000000
# max      167000.000000
# Name: Income, dtype: float64

# %%
desc_df.Income.describe().loc[["mean", "std"]]
# Out:
# mean    75372.881356
# std     26982.688131
# Name: Income, dtype: float64

# %%
# t검정
female_income = desc_df.query('Sex == "Female"')['Income']
male_income = desc_df.query('Sex == "Male"')['Income']
tv, pv = ttest_ind(female_income, male_income, equal_var = True)
print("t-statitics: ", round(tv, 5))
print("p-value: ", round(pv, 5))
if pv < 0.05:
  print("significant")
else:
  print("not significant")
# Out:
# t-statitics:  -3.21161
# p-value:  0.00217
# significant

# %%
# 카이제곱검정
tab = pd.crosstab(desc_df.Race, desc_df.Sex)
print(tab)
print("\n")
print(chi2_contingency(tab))
print("\n")
result = chi2_contingency(tab)
chiv = result[0]
pv = result[1]
print("chi2-statitics: ", round(chiv, 5))
print("p-value: ", round(pv, 5))
if pv < 0.05:
  print("significant")
else:
  print("not significant")
print("expected frequency")
print(result[3])
f_pct = ((result[3] < 5).sum() / (result[3].shape[0] * result[3].shape[1])) * 100
print(str(round(f_pct,2)) + "%")
if f_pct >= 20:
  print("Fisher Exact Test!")
else:
  print("No Fisher Exact Test!")
# Out:
# Sex               Female  Male
# Race
# American Indian        0     2
# Asian                  0     4
# Black                  7     6
# Hispanic               4     8
# Pacific Islander       0     1
# White                 10    17
#
#
# Chi2ContingencyResult(statistic=5.809045405536633, pvalue=0.32524532718433313, dof=5, expected_freq=array([[ 0.71186441,  1.28813559],
#        [ 1.42372881,  2.57627119],
#        [ 4.62711864,  8.37288136],
#        [ 4.27118644,  7.72881356],
#        [ 0.3559322 ,  0.6440678 ],
#        [ 9.61016949, 17.38983051]]))
#
#
# chi2-statitics:  5.80905
# p-value:  0.32525
# not significant
# expected frequency
# [[ 0.71186441  1.28813559]
#  [ 1.42372881  2.57627119]
#  [ 4.62711864  8.37288136]
#  [ 4.27118644  7.72881356]
#  [ 0.3559322   0.6440678 ]
#  [ 9.61016949 17.38983051]]
# 66.67%
# Fisher Exact Test!

# %%
# 피셔 정확 검정
tab = np.array(tab)
result = stats.fisher_test(tab)
print(result)
print(result[0])
pv = result[0][0]
print(pv)
print("p-value: ", round(pv, 5))
if pv < 0.05:
  print("significant")
else:
  print("not significant")
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  structure(c(0L, 0L, 7L, 4L, 0L, 10L, 2L, 4L, 6L, 8L, 1L, 17L), dim = c(6L, 2L))
# p-value = 0.4008
# alternative hypothesis: two.sided
#
#
# [1] 0.400762
#
# 0.400761953244126
# p-value:  0.40076
# not significant

# %%
tab = pd.crosstab(desc_df.HouseholdSize, desc_df.Sex)
print(tab)
print("\n")
print(chi2_contingency(tab))
print("\n")
result = chi2_contingency(tab)
chiv = result[0]
pv = result[1]
print("chi2-statitics: ", round(chiv, 5))
print("p-value: ", round(pv, 5))
if pv < 0.05:
  print("significant")
else:
  print("not significant")
print("expected frequency")
print(result[3])
f_pct = ((result[3] < 5).sum() / (result[3].shape[0] * result[3].shape[1])) * 100
print(str(round(f_pct,2)) + "%")
if f_pct >= 20:
  print("Fisher Exact Test!")
else:
  print("No Fisher Exact Test!")
# Out:
# Sex            Female  Male
# HouseholdSize
# 1                   4     6
# 2                   4     7
# 3                   5     9
# 4                   2     8
# 5                   6     8
#
#
# Chi2ContingencyResult(statistic=1.4705351039937513, pvalue=0.8318476716826708, dof=4, expected_freq=array([[3.55932203, 6.44067797],
#        [3.91525424, 7.08474576],
#        [4.98305085, 9.01694915],
#        [3.55932203, 6.44067797],
#        [4.98305085, 9.01694915]]))
#
#
# chi2-statitics:  1.47054
# p-value:  0.83185
# not significant
# expected frequency
# [[3.55932203 6.44067797]
#  [3.91525424 7.08474576]
#  [4.98305085 9.01694915]
#  [3.55932203 6.44067797]
#  [4.98305085 9.01694915]]
# 50.0%
# Fisher Exact Test!

# %%
tab = np.array(tab)
result = stats.fisher_test(tab)
print(result)
print(result[0])
pv = result[0][0]
print(pv)
print("p-value: ", round(pv, 5))
if pv < 0.05:
  print("significant")
else:
  print("not significant")
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  structure(c(4L, 4L, 5L, 2L, 6L, 6L, 7L, 9L, 8L, 8L), dim = c(5L, 2L))
# p-value = 0.8503
# alternative hypothesis: two.sided
#
#
# [1] 0.850317
#
# 0.8503170108227862
# p-value:  0.85032
# not significant

# %%
tab = pd.crosstab(desc_df.Satisfaction, desc_df.Sex)
print(tab)
print("\n")
print(chi2_contingency(tab))
print("\n")
result = chi2_contingency(tab)
chiv = result[0]
pv = result[1]
print("chi2-statitics: ", round(chiv, 5))
print("p-value: ", round(pv, 5))
if pv < 0.05:
  print("significant")
else:
  print("not significant")
print("expected frequency")
print(result[3])
f_pct = ((result[3] < 5).sum() / (result[3].shape[0] * result[3].shape[1])) * 100
print(str(round(f_pct,2)) + "%")
if f_pct >= 20:
  print("Fisher Exact Test!")
else:
  print("No Fisher Exact Test!")
# Out:
# Sex                    Female  Male
# Satisfaction
# Neutral                     1     6
# Somewhat Dissatisfied       3     3
# Somewhat Satisfied         11    21
# Very Dissatisfied           2     2
# Very Satisfied              4     6
#
#
# Chi2ContingencyResult(statistic=2.397139052989616, pvalue=0.663144348129268, dof=4, expected_freq=array([[ 2.49152542,  4.50847458],
#        [ 2.13559322,  3.86440678],
#        [11.38983051, 20.61016949],
#        [ 1.42372881,  2.57627119],
#        [ 3.55932203,  6.44067797]]))
#
#
# chi2-statitics:  2.39714
# p-value:  0.66314
# not significant
# expected frequency
# [[ 2.49152542  4.50847458]
#  [ 2.13559322  3.86440678]
#  [11.38983051 20.61016949]
#  [ 1.42372881  2.57627119]
#  [ 3.55932203  6.44067797]]
# 70.0%
# Fisher Exact Test!

# %%
tab = np.array(tab)
result = stats.fisher_test(tab)
print(result)
print(result[0])
pv = result[0][0]
print(pv)
print("p-value: ", round(pv, 5))
if pv < 0.05:
  print("significant")
else:
  print("not significant")
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  structure(c(1L, 3L, 11L, 2L, 4L, 6L, 3L, 21L, 2L, 6L), dim = c(5L, 2L))
# p-value = 0.6617
# alternative hypothesis: two.sided
#
#
# [1] 0.6617458
#
# 0.6617457992615556
# p-value:  0.66175
# not significant

# %%
tab = pd.crosstab(desc_df.Channel, desc_df.Sex)
print(tab)
print("\n")
print(chi2_contingency(tab))
print("\n")
result = chi2_contingency(tab)
chiv = result[0]
pv = result[1]
print("chi2-statitics: ", round(chiv, 5))
print("p-value: ", round(pv, 5))
if pv < 0.05:
  print("significant")
else:
  print("not significant")
print("expected frequency")
print(result[3])
f_pct = ((result[3] < 5).sum() / (result[3].shape[0] * result[3].shape[1])) * 100
print(str(round(f_pct,2)) + "%")
if f_pct >= 20:
  print("Fisher Exact Test!")
else:
  print("No Fisher Exact Test!")
# Out:
# Sex       Female  Male
# Channel
# Referral       6     6
# SM             3    16
# TV             4     9
# Web            8     7
#
#
# Chi2ContingencyResult(statistic=6.528156761674767, pvalue=0.08855866046491273, dof=3, expected_freq=array([[ 4.27118644,  7.72881356],
#        [ 6.76271186, 12.23728814],
#        [ 4.62711864,  8.37288136],
#        [ 5.33898305,  9.66101695]]))
#
#
# chi2-statitics:  6.52816
# p-value:  0.08856
# not significant
# expected frequency
# [[ 4.27118644  7.72881356]
#  [ 6.76271186 12.23728814]
#  [ 4.62711864  8.37288136]
#  [ 5.33898305  9.66101695]]
# 25.0%
# Fisher Exact Test!

# %%
tab = np.array(tab)
result = stats.fisher_test(tab)
print(result)
print(result[0])
pv = result[0][0]
print(pv)
print("p-value: ", round(pv, 5))
if pv < 0.05:
  print("significant")
else:
  print("not significant")
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  structure(c(6L, 3L, 4L, 8L, 6L, 16L, 9L, 7L), dim = c(4L, 2L))
# p-value = 0.08059
# alternative hypothesis: two.sided
#
#
# [1] 0.08059186
#
# 0.08059185685217439
# p-value:  0.08059
# not significant

# %% [markdown]
# # 데이터 분석 프로젝트

# %% [markdown]
# ## 한국복지패널 데이터 분석 준비하기

# %%
# 한글 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 메뉴 - 런타임 - 세션 다시 시작
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (7,339 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# 한글 폰트 지정
plt.rc("font", family = "NanumGothic")

# %%
# 데이터 불러오기
raw_welfare = pd.read_csv('/content/drive/MyDrive/lsda02/data/welfare_2015.csv')

# %%
# 복사본 만들기
welfare = raw_welfare.copy()

# %%
# 데이터 앞부분, 뒷부분 출력
print(welfare)
print(welfare.head())
print(welfare.tail())
# Out:
#        h10_g3  h10_g4  h10_g10  h10_g11  h10_eco9  p1002_8aq1  h10_reg7
# 0           2    1936        2        2       NaN         NaN         1
# 1           2    1945        2        2       NaN         NaN         1
# 2           1    1948        2        2     942.0       120.0         1
# 3           1    1942        3        1     762.0       200.0         1
# 4           2    1923        2        1       NaN         NaN         1
# ...       ...     ...      ...      ...       ...         ...       ...
# 16665       2    9999        5        1       NaN         NaN         6
# 16666       1    1972        9        1       NaN         NaN         6
# 16667       2    1969        1        9       NaN         NaN         2
# 16668       2    1960        3        2    9999.0         NaN         6
# 16669       1    1940        1        1       NaN      9999.0         5
#
# [16670 rows x 7 columns]
#    h10_g3  h10_g4  h10_g10  h10_g11  h10_eco9  p1002_8aq1  h10_reg7
# 0       2    1936        2        2       NaN         NaN         1
# 1       2    1945        2        2       NaN         NaN         1
# 2       1    1948        2        2     942.0       120.0         1
# 3       1    1942        3        1     762.0       200.0         1
# 4       2    1923        2        1       NaN         NaN         1
#        h10_g3  h10_g4  h10_g10  h10_g11  h10_eco9  p1002_8aq1  h10_reg7
# 16665       2    9999        5        1       NaN         NaN         6
# 16666       1    1972        9        1       NaN         NaN         6
# 16667       2    1969        1        9       NaN         NaN         2
# 16668       2    1960        3        2    9999.0         NaN         6
# 16669       1    1940        1        1       NaN      9999.0         5

# %%
welfare.shape       # 행, 열 개수 출력
# Out:
# (16670, 7)

# %%
welfare.info()      # 변수 속성 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   h10_g3      16670 non-null  int64
#  1   h10_g4      16670 non-null  int64
#  2   h10_g10     16670 non-null  int64
#  3   h10_g11     16670 non-null  int64
#  4   h10_eco9    7530 non-null   float64
#  5   p1002_8aq1  4635 non-null   float64
#  6   h10_reg7    16670 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 911.8 KB

# %%
welfare.describe()  # 요약 통계량
# Out:
#              h10_g3        h10_g4       h10_g10       h10_g11     h10_eco9  \
# count  16670.000000  16670.000000  16670.000000  16670.000000  7530.000000
# mean       1.545711   1968.047391      1.648410      1.517516   592.493094
# std        0.501283     66.738241      1.572843      0.503058   277.804427
# min        1.000000   1907.000000      0.000000      1.000000   111.000000
# 25%        1.000000   1946.000000      1.000000      1.000000   314.000000
# 50%        2.000000   1966.000000      1.000000      2.000000   611.000000
# 75%        2.000000   1988.000000      2.000000      2.000000   863.000000
# max        9.000000   9999.000000      9.000000      9.000000  9999.000000
#
#         p1002_8aq1      h10_reg7
# count  4635.000000  16670.000000
# mean    243.724168      3.705099
# std     233.549988      2.069236
# min       0.000000      1.000000
# 25%     122.000000      2.000000
# 50%     192.500000      3.000000
# 75%     316.650000      6.000000
# max    9999.000000      7.000000

# %%
welfare = welfare.rename(columns={'h10_g3':'sex', #  성별
                                  'h10_g4':'birth_year', #  태어난 연도
                                  'h10_g10':'marital_status', #  혼인 상태
                                  'h10_g11':'religion', #  종교
                                  'h10_eco9':'job_code', #  월급
                                  'p1002_8aq1':'income', #  직업 코드
                                  'h10_reg7':'region_code'}) #  지역 코드

# %%
welfare.head()
# Out:
#    sex  birth_year  marital_status  religion  job_code  income  region_code
# 0    2        1936               2         2       NaN     NaN            1
# 1    2        1945               2         2       NaN     NaN            1
# 2    1        1948               2         2     942.0   120.0            1
# 3    1        1942               3         1     762.0   200.0            1
# 4    2        1923               2         1       NaN     NaN            1

# %% [markdown]
# ## 1 성별에 따른 월급 차이 - '성별에 따라 월급이 다를까?'

# %% [markdown]
# ### 성별 변수 검토 및 전처리하기

# %% [markdown]
# #### 1. 변수 검토하기

# %%
welfare['sex'].dtypes  # 변수 타입 출력
# Out:
# dtype('int64')

# %%
welfare['sex'].value_counts()  # 빈도 구하기
# Out:
# sex
# 2    9089
# 1    7580
# 9       1
# Name: count, dtype: int64

# %% [markdown]
# #### 2. 전처리

# %%
# 이상치 확인
welfare['sex'].value_counts(dropna = False)
# 9 => 코드북 상으로 모름/무응답(미상)
# Out:
# sex
# 2    9089
# 1    7580
# 9       1
# Name: count, dtype: int64

# %%
# 이상치 결측 처리
welfare['sex'] = np.where(welfare['sex'] == 9, np.nan, welfare['sex'])

# %%
# 이상치, 결측치 확인
welfare['sex'].value_counts(dropna = False)
# Out:
# sex
# 2.0    9089
# 1.0    7580
# NaN       1
# Name: count, dtype: int64

# %%
# 결측치 확인
welfare['sex'].isnull().sum()
# Out:
# 1

# %%
# 성별 항목 이름 부여
welfare['sex'] = np.where(welfare['sex'] == 1, 'male',
                          np.where(welfare['sex'] == 2, 'female', np.nan))

# %%
# 빈도 구하기
welfare['sex'].value_counts(dropna = False)
# Out:
# sex
# female    9089
# male      7580
# nan          1
# Name: count, dtype: int64

# %%
#  nan 문자열을 NaN 으로 변환
welfare['sex'] = np.where(welfare['sex'] == 'nan', np.nan, welfare['sex'])

# %%
# 빈도 구하기
welfare['sex'].value_counts(dropna = False)
# Out:
# sex
# female    9089
# male      7580
# NaN          1
# Name: count, dtype: int64

# %%
# 빈도 막대 그래프 만들기
sns.countplot(x = 'sex', data = welfare)
plt.show()

# %% [markdown]
# ### 월급 변수 검토 및 전처리하기

# %% [markdown]
# #### 1. 변수 검토하기

# %%
welfare['income'].dtypes  # 변수 타입 출력
# Out:
# dtype('float64')

# %%
welfare['income'].describe()  # 요약 통계량 구하기
# Out:
# count    4635.000000
# mean      243.724168
# std       233.549988
# min         0.000000
# 25%       122.000000
# 50%       192.500000
# 75%       316.650000
# max      9999.000000
# Name: income, dtype: float64

# %% [markdown]
# #### 2. 전처리

# %%
welfare['income'].describe()  # 이상치 확인
# 월급이 0 => 소득이 없음
# 월급이 9999 => 코드북 상으로 모름/무응답(미상)
# Out:
# count    4635.000000
# mean      243.724168
# std       233.549988
# min         0.000000
# 25%       122.000000
# 50%       192.500000
# 75%       316.650000
# max      9999.000000
# Name: income, dtype: float64

# %%
welfare['income'].isnull().sum()  # 결측치 확인
# Out:
# 12035

# %%
# 빈도 구하기
welfare['income'].value_counts(dropna = False)
# Out:
# income
# NaN        12035
# 20.00        136
# 150.00       128
# 200.00        91
# 250.00        74
#            ...
# 392.70         1
# 515.00         1
# 397.18         1
# 304.16         1
# 9999.00        1
# Name: count, Length: 1769, dtype: int64

# %%
# 이상치 결측 처리 - 9999
welfare['income'] = np.where(welfare['income'] == 9999, np.nan, welfare['income'])

# %%
# 결측치 확인
welfare['income'].isnull().sum()
# Out:
# 12036

# %%
# 빈도 구하기
welfare['income'].value_counts(dropna = False)
# Out:
# income
# NaN       12036
# 20.00       136
# 150.00      128
# 200.00       91
# 250.00       74
#           ...
# 515.00        1
# 397.18        1
# 304.16        1
# 487.50        1
# 187.66        1
# Name: count, Length: 1768, dtype: int64

# %%
welfare['income'].describe()  # 이상치 확인
# Out:
# count    4634.000000
# mean      241.619016
# std       184.423869
# min         0.000000
# 25%       122.000000
# 50%       192.500000
# 75%       316.600000
# max      2400.000000
# Name: income, dtype: float64

# %%
# 이상치 결측 처리 - 0
welfare['income'] = np.where(welfare['income'] == 0, np.nan, welfare['income'])

# %%
# 결측치 확인
welfare['income'].isnull().sum()
# Out:
# 12050

# %%
# 빈도 구하기
welfare['income'].value_counts(dropna = False)
# Out:
# income
# NaN       12050
# 20.00       136
# 150.00      128
# 200.00       91
# 250.00       74
#           ...
# 515.00        1
# 397.18        1
# 304.16        1
# 487.50        1
# 187.66        1
# Name: count, Length: 1767, dtype: int64

# %%
sns.histplot(x = 'income', data = welfare)  # 히스토그램 만들기
plt.show()

# %%
# 평균 월급 천만원 이내에 많이 모여 있으므로 자세히 보기 위해 축 범위 변경
sns.histplot(x = 'income', data = welfare).set(xlim = (0,1000))  # 히스토그램 만들기
plt.show()

# %% [markdown]
# ### 성별에 따른 월급 차이 분석하기

# %% [markdown]
# #### 1. 성별 월급 평균표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16670 non-null  int64
#  2   marital_status  16670 non-null  int64
#  3   religion        16670 non-null  int64
#  4   job_code        7530 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 911.8+ KB

# %%
welfare.dropna(subset = ['sex','income'])
# Out:
#           sex  birth_year  marital_status  religion  job_code  income  \
# 2        male        1948               2         2     942.0  120.00
# 3        male        1942               3         1     762.0  200.00
# 18       male        1962               5         2     999.0   40.00
# 19       male        1978               1         2     312.0  350.00
# 20     female        1975               1         2     254.0  200.00
# ...       ...         ...             ...       ...       ...     ...
# 16639    male        1956               3         1     873.0  162.00
# 16642    male        1966               1         1     873.0  188.00
# 16643  female        1962               1         1     899.0   90.00
# 16654    male        1956               1         2     743.0  187.66
# 16660  female        1992               5         1     314.0  302.50
#
#        region_code
# 2                1
# 3                1
# 18               1
# 19               1
# 20               1
# ...            ...
# 16639            6
# 16642            6
# 16643            6
# 16654            6
# 16660            5
#
# [4620 rows x 7 columns]

# %%
# 하나씩 해보자!
sex_income_test = welfare.dropna(subset = ['sex','income'])

# %%
sex_income_test.sex.value_counts(dropna=False)
# Out:
# sex
# male      2452
# female    2168
# Name: count, dtype: int64

# %%
sex_income_test.income.describe()
# Out:
# count    4620.000000
# mean      242.351195
# std       184.222067
# min         0.460000
# 25%       123.000000
# 50%       193.000000
# 75%       316.700000
# max      2400.000000
# Name: income, dtype: float64

# %%
sex_income_test.income.value_counts(dropna=False)
# Out:
# income
# 20.00     136
# 150.00    128
# 200.00     91
# 250.00     74
# 120.00     71
#          ...
# 515.00      1
# 397.18      1
# 304.16      1
# 487.50      1
# 187.66      1
# Name: count, Length: 1766, dtype: int64

# %%
# as_index = True => 그룹 이름을 행 인덱스로 사용
grouped = sex_income_test.groupby('sex')
print(grouped.agg({'income': 'mean'}))
print(grouped.agg({'income': ['mean','std']}))
grouped.agg(mean_income = ('income', 'mean'), sd_income = ('income', 'std')) # 튜플 형태
# Out:
#             income
# sex
# female  163.247085
# male    312.293165
#             income
#               mean         std
# sex
# female  163.247085  126.053981
# male    312.293165  198.694969
#         mean_income   sd_income
# sex
# female   163.247085  126.053981
# male     312.293165  198.694969

# %%
# as_index = False => 그룹 이름을 행 인덱스로 사용하지 않게 설정
grouped = sex_income_test.groupby('sex', as_index = False)
print(grouped.agg({'income': 'mean'}))
print(grouped.agg({'income': ['mean','std']}))
grouped.agg(mean_income = ('income', 'mean'), sd_income = ('income', 'std')) # 튜플 형태
# Out:
#       sex      income
# 0  female  163.247085
# 1    male  312.293165
#       sex      income
#                  mean         std
# 0  female  163.247085  126.053981
# 1    male  312.293165  198.694969
#       sex  mean_income   sd_income
# 0  female   163.247085  126.053981
# 1    male   312.293165  198.694969

# %%
# 하나씩 한 내용 종합하여 한번에 처리

# 성별 월급 평균표 만들기
# 그룹 이름을 행 인덱스로 사용하지 않게 설정
sex_income = welfare.dropna(subset = ['sex','income']). \
                     groupby('sex', as_index = False). \
                     agg(mean_income = ('income', 'mean'))
sex_income
# income 결측치 제거
# sex별 분리
# income 평균 구하기
# Out:
#       sex  mean_income
# 0  female   163.247085
# 1    male   312.293165

# %%
sex_income_diff = sex_income.iloc[1,1] - sex_income.iloc[0,1]
sex_income_diff
# Out:
# 149.04607989260967

# %% [markdown]
# #### 2. 그래프 만들기

# %%
# 막대 그래프 만들기
sns.barplot(x = 'sex', y = 'mean_income', data = sex_income)
plt.show()
# 추가 분석 진행 - 독립표본 t검정 & 유의확률

# %%
# 막대 그래프 만들기
sns.barplot(x = 'sex', y = 'mean_income', data = sex_income)
for i, j in enumerate(sex_income["mean_income"]):
  plt.annotate(round(j), (i, j), xytext = (0, 2), textcoords = 'offset points', fontsize = 8, ha = 'center', color = 'black')
plt.show()

# %% [markdown]
# # 중간 데이터 저장

# %%
welfare.to_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv', index = False)

# %%
# 데이터 불러오기
welfare = pd.read_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv')

# %% [markdown]
# ## 2 나이와 월급의 관계 - '몇 살 때 월급을 가장 많이 받을까?'

# %% [markdown]
# ### 나이 변수 검토 및 전처리하기

# %% [markdown]
# #### 1. 변수 검토하기

# %%
welfare['birth_year'].dtypes  # 변수 타입 출력
# Out:
# dtype('int64')

# %%
welfare['birth_year'].describe()  # 요약 통계량 구하기
# Out:
# count    16670.000000
# mean      1968.047391
# std         66.738241
# min       1907.000000
# 25%       1946.000000
# 50%       1966.000000
# 75%       1988.000000
# max       9999.000000
# Name: birth_year, dtype: float64

# %%
# 빈도 구하기
welfare['birth_year'].value_counts(dropna = False)
# Out:
# birth_year
# 1942    354
# 1939    300
# 1940    294
# 1938    279
# 1947    269
#        ...
# 1914      1
# 1911      1
# 1917      1
# 1915      1
# 9999      1
# Name: count, Length: 103, dtype: int64

# %%
sns.histplot(x = 'birth_year', data = welfare).set(xlim = (1900,2020))  # 히스토그램 만들기
plt.show()

# %% [markdown]
# #### 2. 전처리

# %%
welfare['birth_year'].describe()  # 이상치 확인
# 9999 => 코드북 상으로 모름/무응답(미상)
# Out:
# count    16670.000000
# mean      1968.047391
# std         66.738241
# min       1907.000000
# 25%       1946.000000
# 50%       1966.000000
# 75%       1988.000000
# max       9999.000000
# Name: birth_year, dtype: float64

# %%
welfare['birth_year'].isnull().sum()  # 결측치 확인
# Out:
# 0

# %%
# 빈도 구하기
welfare['birth_year'].value_counts(dropna = False)
# Out:
# birth_year
# 1942    354
# 1939    300
# 1940    294
# 1938    279
# 1947    269
#        ...
# 1914      1
# 1911      1
# 1917      1
# 1915      1
# 9999      1
# Name: count, Length: 103, dtype: int64

# %%
# 이상치 결측 처리
welfare['birth_year'] = np.where(welfare['birth_year'] == 9999, np.nan, welfare['birth_year'])

# %%
# 결측치 확인
welfare['birth_year'].isnull().sum()
# Out:
# 1

# %%
# 빈도 구하기
welfare['birth_year'].value_counts(dropna = False)
# Out:
# birth_year
# 1942.0    354
# 1939.0    300
# 1940.0    294
# 1938.0    279
# 1947.0    269
#          ...
# 1914.0      1
# 1911.0      1
# 1917.0      1
# 1915.0      1
# NaN         1
# Name: count, Length: 103, dtype: int64

# %%
welfare['birth_year'].describe()  # 이상치 확인
# Out:
# count    16669.000000
# mean      1967.565601
# std         24.177789
# min       1907.000000
# 25%       1946.000000
# 50%       1966.000000
# 75%       1988.000000
# max       2014.000000
# Name: birth_year, dtype: float64

# %% [markdown]
# #### 3. 파생변수 만들기 - 나이

# %%
welfare['age'] = 2015 - welfare['birth_year'] + 1

# %%
welfare.head()
# Out:
#       sex  birth_year  marital_status  religion  job_code  income  \
# 0  female      1936.0               2         2       NaN     NaN
# 1  female      1945.0               2         2       NaN     NaN
# 2    male      1948.0               2         2     942.0   120.0
# 3    male      1942.0               3         1     762.0   200.0
# 4  female      1923.0               2         1       NaN     NaN
#
#    region_code   age
# 0            1  80.0
# 1            1  71.0
# 2            1  68.0
# 3            1  74.0
# 4            1  93.0

# %%
# 결측치 확인
welfare['age'].isnull().sum()
# Out:
# 1

# %%
# 빈도 구하기
welfare['age'].value_counts(dropna = False)
# Out:
# age
# 74.0     354
# 77.0     300
# 76.0     294
# 78.0     279
# 69.0     269
#         ...
# 102.0      1
# 105.0      1
# 99.0       1
# 101.0      1
# NaN        1
# Name: count, Length: 103, dtype: int64

# %%
welfare['age'].describe() # 요약 통계량 구하기
# Out:
# count    16669.000000
# mean        48.434399
# std         24.177789
# min          2.000000
# 25%         28.000000
# 50%         50.000000
# 75%         70.000000
# max        109.000000
# Name: age, dtype: float64

# %%
sns.histplot(x = 'age', data = welfare)  # 히스토그램 만들기
plt.show()

# %% [markdown]
# ### 나이와 월급의 관계 분석하기

# %% [markdown]
# #### 1. 나이에 따른 월급 평균표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16670 non-null  int64
#  4   job_code        7530 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 1.0+ MB

# %%
# 나이별 월급 평균표 만들기
age_income = welfare.dropna(subset = ['age','income']) \
                    .groupby('age', as_index = False) \
                    .agg(mean_income = ('income', 'mean'))
# 결측치 제거
# age별 분리
# income 평균 구하기
age_income.head()
# Out:
#     age  mean_income
# 0  20.0   121.300000
# 1  21.0   105.518519
# 2  22.0   130.092258
# 3  23.0   141.715652
# 4  24.0   134.087736

# %%
# 평균 월급 최대값 나이 확인
max_age_income = age_income.mean_income.max()
print(max_age_income)
age_income[age_income['mean_income'] == max_age_income]
# age_income[age_income.mean_income == age_income.mean_income.max()]
# Out:
# 318.6777477477478
#      age  mean_income
# 33  53.0   318.677748

# %%
max_age_income_index = np.argmax(age_income['mean_income'])
print(max_age_income_index)
age_income.iloc[max_age_income_index,:]
# Out:
# 33
# age             53.000000
# mean_income    318.677748
# Name: 33, dtype: float64

# %% [markdown]
# #### 2.  그래프 만들기

# %%
# 선 그래프 만들기
sns.lineplot(x = 'age', y = 'mean_income', data = age_income)
plt.show()

# %% [markdown]
# # 중간 데이터 저장

# %%
welfare.to_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv', index = False)

# %%
# 데이터 불러오기
welfare = pd.read_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv')

# %% [markdown]
# ## 3 연령대에 따른 월급 차이 - 어떤 연령대의 월급이 가장 많을까?

# %% [markdown]
# ### 연령대 변수 검토 및 전처리하기

# %% [markdown]
# #### 파생변수 만들기 - 연령대

# %%
# 나이 변수 살펴보기
welfare['age'].head()
# Out:
# 0    80.0
# 1    71.0
# 2    68.0
# 3    74.0
# 4    93.0
# Name: age, dtype: float64

# %%
welfare['age'].describe() # 요약 통계량 구하기
# Out:
# count    16669.000000
# mean        48.434399
# std         24.177789
# min          2.000000
# 25%         28.000000
# 50%         50.000000
# 75%         70.000000
# max        109.000000
# Name: age, dtype: float64

# %%
# 결측치 확인
welfare['age'].isnull().sum()
# Out:
# 1

# %%
# 빈도 구하기
welfare['age'].value_counts(dropna = False)
# Out:
# age
# 74.0     354
# 77.0     300
# 76.0     294
# 78.0     279
# 69.0     269
#         ...
# 102.0      1
# 105.0      1
# 99.0       1
# 101.0      1
# NaN        1
# Name: count, Length: 103, dtype: int64

# %%
# 연령대 변수 만들기
# 60 세 이상 = old
# 30 ~ 59 세 = middle
# ~ 29 세 = young
welfare['age_group'] = np.where(welfare['age'].isnull() == True, np.nan,
                                np.where(welfare['age'] >=  60, 'old',
                                         np.where(welfare['age'] >= 30, 'middle', 'young')))

# %%
# 빈도 구하기
welfare['age_group'].value_counts(dropna = False)
# Out:
# age_group
# old       6283
# middle    6052
# young     4334
# nan          1
# Name: count, dtype: int64

# %%
# 결측치 확인
welfare['age_group'].isnull().sum()
# Out:
# 0

# %%
# 문자열 nan 을 NaN 으로 변환
welfare['age_group'] = np.where(welfare['age_group'] == 'nan', np.nan, welfare['age_group'])

# %%
# 결측치 확인
welfare['age_group'].isnull().sum()
# Out:
# 1

# %%
# 빈도 구하기
welfare['age_group'].value_counts(dropna = False)
# Out:
# age_group
# old       6283
# middle    6052
# young     4334
# NaN          1
# Name: count, dtype: int64

# %%
# 빈도 막대 그래프 만들기
sns.countplot(x = 'age_group', data = welfare)
plt.show()

# %% [markdown]
# ### 연령대에 따른 월급 차이 분석하기

# %% [markdown]
# #### 1. 연령대별 월급 평균표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16670 non-null  int64
#  4   job_code        7530 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 1.1+ MB

# %%
# 연령대별 월급 평균표 만들기
age_group_income = welfare.dropna(subset = ['age_group','income']) \
                     .groupby('age_group', as_index = False) \
                     .agg(mean_income = ('income', 'mean'))
# 결측치 제거
# age_group 별 분리
# income 평균 구하기
age_group_income
# Out:
#   age_group  mean_income
# 0    middle   281.887100
# 1       old   125.329463
# 2     young   163.595331

# %%
# middle 과 old 의 평균 월급 차이
print(age_group_income.iloc[0,1] - age_group_income.iloc[1,1])
# middle 과 young 의 평균 월급 차이
print(age_group_income.iloc[0,1] - age_group_income.iloc[2,1])
# young 과 old 의 평균 월급 차이
print(age_group_income.iloc[2,1] - age_group_income.iloc[1,1])
# Out:
# 156.55763727873892
# 118.29176987126272
# 38.26586740747621

# %% [markdown]
# #### 2. 그래프 만들기

# %%
# 막대 그래프 만들기
sns.barplot(x = 'age_group', y = 'mean_income', data = age_group_income)
plt.show()
# 추가 분석 진행 - 단순분산분석 & 사후검정

# %%
# 막대 정렬하기
sns.barplot(x = 'age_group', y = 'mean_income',
            data = age_group_income, order = ['young', 'middle', 'old'])
plt.show()

# %% [markdown]
# # 중간 데이터 저장

# %%
welfare.to_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv', index = False)

# %%
# 데이터 불러오기
welfare = pd.read_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv')

# %% [markdown]
# ## 4 연령대 및 성별 월급 차이 - 성별 월급 차이는 연령대별로 다를까?

# %% [markdown]
# ### 연령대 및 성별 월급 차이 분석하기

# %% [markdown]
# #### 1. 연령대 및 성별 월급 평균표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16670 non-null  int64
#  4   job_code        7530 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 1.1+ MB

# %%
# 연령대 및 성별 평균표 만들기
age_group_sex_income = welfare.dropna(subset = ['age_group','sex','income']) \
                    .groupby(['age_group', 'sex'], as_index = False) \
                    .agg(mean_income = ('income', 'mean'))
# income 결측치 제거
# ageg 및 sex별 분리
# income 평균 구하기
age_group_sex_income
# Out:
#   age_group     sex  mean_income
# 0    middle  female   187.975522
# 1    middle    male   353.075741
# 2       old  female    81.529169
# 3       old    male   173.855579
# 4     young  female   159.505178
# 5     young    male   170.817371

# %%
# 중년의 남성과 여성의 평균 월급 차이
print(age_group_sex_income.iloc[1,2] - age_group_sex_income.iloc[0,2])
# 노년의 남성과 여성의 평균 월급 차이
print(age_group_sex_income.iloc[3,2] - age_group_sex_income.iloc[2,2])
# Out:
# 165.1002190854017
# 92.32641030128764

# %% [markdown]
# #### 2. 그래프 만들기

# %%
# 막대 그래프 만들기
sns.barplot(x = 'age_group', y = 'mean_income', hue = 'sex',
            data = age_group_sex_income, order = ['young', 'middle', 'old'])
plt.show()

# %% [markdown]
# ### 나이 및 성별 월급 차이 분석하기

# %% [markdown]
# #### 1. 나이 및 성별 월급 평균표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16670 non-null  int64
#  4   job_code        7530 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 1.1+ MB

# %%
# 나이 및 성별 월급 평균표 만들기
age_sex_income = welfare.dropna(subset = ['age', 'sex', 'income']) \
                 .groupby(['age', 'sex'], as_index = False) \
                 .agg(mean_income = ('income', 'mean'))
# 결측치 제거
# age 및 sex별 분리
# income 평균 구하기
age_sex_income.head()
# Out:
#     age     sex  mean_income
# 0  20.0  female   147.450000
# 1  20.0    male    69.000000
# 2  21.0  female   106.978947
# 3  21.0    male   102.050000
# 4  22.0  female   139.854706

# %%
# 평균 월급 최대값 나이 확인
max_age_sex_income = age_sex_income.mean_income.max()
print(max_age_sex_income)
age_sex_income[age_sex_income['mean_income'] == max_age_sex_income]
# Out:
# 434.48900000000003
#      age   sex  mean_income
# 69  54.0  male      434.489

# %% [markdown]
# #### 2. 그래프 만들기

# %%
# 선 그래프 만들기
sns.lineplot(x = 'age', y = 'mean_income', hue = 'sex', data = age_sex_income)
plt.show()

# %% [markdown]
# # 중간 데이터 저장

# %%
welfare.to_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv', index = False)

# %%
# 데이터 불러오기
welfare = pd.read_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv')

# %% [markdown]
# ## 5 직업별 월급 차이 - 어떤 직업이 월급을 가장 많이 받을까?
#
# ### 직업 변수 검토 및 전처리하기
#
# #### 1. 변수 검토하기

# %%
welfare['job_code'].dtypes  # 변수 타입 출력
# Out:
# dtype('float64')

# %%
welfare['job_code'].value_counts()  # 빈도 구하기
# Out:
# job_code
# 611.0     1320
# 521.0      353
# 941.0      325
# 930.0      289
# 312.0      260
#           ...
# 881.0        2
# 1011.0       2
# 620.0        2
# 812.0        1
# 9999.0       1
# Name: count, Length: 146, dtype: int64

# %% [markdown]
# #### 2. 전처리

# %%
welfare['job_code'].value_counts(dropna = False)  # 빈도 구하기
# 9999 => 코드북 상으로 모름/무응답(미상)
# Out:
# job_code
# NaN       9140
# 611.0     1320
# 521.0      353
# 941.0      325
# 930.0      289
#           ...
# 881.0        2
# 620.0        2
# 1011.0       2
# 812.0        1
# 9999.0       1
# Name: count, Length: 147, dtype: int64

# %%
# 결측치 확인
welfare['job_code'].isnull().sum()
# Out:
# 9140

# %%
# 이상치 결측 처리
welfare['job_code'] = np.where(welfare['job_code'] == 9999, np.nan, welfare['job_code'])

# %%
welfare['job_code'].value_counts(dropna = False)  # 빈도 구하기
# Out:
# job_code
# NaN       9141
# 611.0     1320
# 521.0      353
# 941.0      325
# 930.0      289
#           ...
# 237.0        2
# 620.0        2
# 1011.0       2
# 876.0        2
# 812.0        1
# Name: count, Length: 146, dtype: int64

# %%
# 결측치 확인
welfare['job_code'].isnull().sum()
# Out:
# 9141

# %%
# 직종코드 데이터 가져오기
job_list = pd.read_excel('/content/drive/MyDrive/lsda02/data/welfare_2015_codebook.xlsx',
                         sheet_name = '직종코드')
# job_list = pd.read_excel('/content/drive/MyDrive/lsda02/data/welfare_2015_codebook.xlsx', sheet_name = 1)
job_list.head()
# Out:
#    job_code                  job
# 0       111  의회의원 고위공무원 및 공공단체임원
# 1       112               기업고위임원
# 2       120        행정 및 경영지원 관리자
# 3       131    연구 교육 및 법률 관련 관리자
# 4       132          보험 및 금융 관리자

# %%
job_list.shape  # 행, 열 개수 출력
# Out:
# (149, 2)

# %%
pd.merge(welfare, job_list, how = 'left', on = 'job_code')
# Out:
#           sex  birth_year  marital_status  religion  job_code  income  \
# 0      female      1936.0               2         2       NaN     NaN
# 1      female      1945.0               2         2       NaN     NaN
# 2        male      1948.0               2         2     942.0   120.0
# 3        male      1942.0               3         1     762.0   200.0
# 4      female      1923.0               2         1       NaN     NaN
# ...       ...         ...             ...       ...       ...     ...
# 16665  female         NaN               5         1       NaN     NaN
# 16666    male      1972.0               9         1       NaN     NaN
# 16667  female      1969.0               1         9       NaN     NaN
# 16668  female      1960.0               3         2       NaN     NaN
# 16669    male      1940.0               1         1       NaN     NaN
#
#        region_code   age age_group        job
# 0                1  80.0       old        NaN
# 1                1  71.0       old        NaN
# 2                1  68.0       old  경비원 및 검표원
# 3                1  74.0       old        전기공
# 4                1  93.0       old        NaN
# ...            ...   ...       ...        ...
# 16665            6   NaN       NaN        NaN
# 16666            6  44.0    middle        NaN
# 16667            2  47.0    middle        NaN
# 16668            6  56.0    middle        NaN
# 16669            5  76.0       old        NaN
#
# [16670 rows x 10 columns]

# %%
welfare.merge(job_list, how = 'left', on = 'job_code')
# Out:
#           sex  birth_year  marital_status  religion  job_code  income  \
# 0      female      1936.0               2         2       NaN     NaN
# 1      female      1945.0               2         2       NaN     NaN
# 2        male      1948.0               2         2     942.0   120.0
# 3        male      1942.0               3         1     762.0   200.0
# 4      female      1923.0               2         1       NaN     NaN
# ...       ...         ...             ...       ...       ...     ...
# 16665  female         NaN               5         1       NaN     NaN
# 16666    male      1972.0               9         1       NaN     NaN
# 16667  female      1969.0               1         9       NaN     NaN
# 16668  female      1960.0               3         2       NaN     NaN
# 16669    male      1940.0               1         1       NaN     NaN
#
#        region_code   age age_group        job
# 0                1  80.0       old        NaN
# 1                1  71.0       old        NaN
# 2                1  68.0       old  경비원 및 검표원
# 3                1  74.0       old        전기공
# 4                1  93.0       old        NaN
# ...            ...   ...       ...        ...
# 16665            6   NaN       NaN        NaN
# 16666            6  44.0    middle        NaN
# 16667            2  47.0    middle        NaN
# 16668            6  56.0    middle        NaN
# 16669            5  76.0       old        NaN
#
# [16670 rows x 10 columns]

# %%
# welfare에 list_job 결합하기
welfare = welfare.merge(job_list, how = 'left', on = 'job_code')
welfare.head()
# Out:
#       sex  birth_year  marital_status  religion  job_code  income  \
# 0  female      1936.0               2         2       NaN     NaN
# 1  female      1945.0               2         2       NaN     NaN
# 2    male      1948.0               2         2     942.0   120.0
# 3    male      1942.0               3         1     762.0   200.0
# 4  female      1923.0               2         1       NaN     NaN
#
#    region_code   age age_group        job
# 0            1  80.0       old        NaN
# 1            1  71.0       old        NaN
# 2            1  68.0       old  경비원 및 검표원
# 3            1  74.0       old        전기공
# 4            1  93.0       old        NaN

# %%
# job_code 결측치 제거하고 code_job, job 출력하여 확인
welfare.dropna(subset = ['job_code'])[['job_code', 'job']].head()
# Out:
#     job_code                   job
# 2      942.0             경비원 및 검표원
# 3      762.0                   전기공
# 5      530.0  방문 노점 및 통신 판매 관련 종사자
# 18     999.0       기타 서비스관련 단순 종사원
# 19     312.0              경영관련 사무원

# %% [markdown]
# ### 직업별 월급 차이 분석하기

# %% [markdown]
# #### 1. 직업별 월급 평균표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16670 non-null  int64
#  4   job_code        7529 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
#  9   job             7529 non-null   object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 1.3+ MB

# %%
# 직업별 월금 평균표 만들기
job_income = welfare.dropna(subset = ['job', 'income']) \
                    .groupby('job', as_index = False) \
                    .agg(mean_income = ('income', 'mean'))
# job, income 결측치 제거
# job별 분리
# income 평균 구하기
job_income.head()
# Out:
#                  job  mean_income
# 0        가사 및 육아 도우미    80.166484
# 1                간호사   240.681270
# 2     건설 및 광업 단순 종사원   190.129744
# 3      건설 및 채굴 기계운전원   357.970000
# 4  건설 전기 및 생산 관련 관리자   535.805556

# %% [markdown]
# #### 3. 그래프 만들기

# %% [markdown]
# **(1) 월급이 많은 직업**

# %%
# 상위 10위 추출 = 내림 차순
top10 = job_income.sort_values('mean_income', ascending = False).head(10)
top10
# Out:
#                        job  mean_income
# 17      금속 재료 공학 기술자 및 시험원   845.066667
# 89                의료진료 전문가   843.642857
# 91     의회의원 고위공무원 및 공공단체임원   750.000000
# 54             보험 및 금융 관리자   726.180000
# 114              제관원 및 판금원   572.406667
# 133          행정 및 경영지원 관리자   563.763333
# 44   문화 예술 디자인 및 영상 관련 관리자   557.466667
# 75       연구 교육 및 법률 관련 관리자   549.912500
# 4        건설 전기 및 생산 관련 관리자   535.805556
# 63       석유 및 화학물 가공장치 조작원   531.660000

# %%
# 막대 그래프 만들기
sns.barplot(y = 'job', x = 'mean_income', data = top10)

plt.show()

# %% [markdown]
# **(2) 월급이 적은 직업**

# %%
# 하위 10위 추출 - 오름차순 정렬
bottom10 = job_income.sort_values('mean_income').head(10)
# bottom10 = job_income.sort_values('mean_income', ascending = True).head(10)
bottom10
# Out:
#                   job  mean_income
# 0         가사 및 육아 도우미    80.166484
# 96           임업관련 종사자    83.330000
# 29    기타 서비스관련 단순 종사원    88.221010
# 122      청소원 및 환경 미화원    88.787747
# 72           약사 및 한약사    89.000000
# 101          작물재배 종사자    92.000000
# 35      농립어업관련 단순 종사원   101.581250
# 88   의료 복지 관련 서비스 종사자   103.526435
# 86        음식관련 단순 종사원   107.845109
# 129       판매관련 단순 종사원   116.822034

# %%
# 막대 그래프 만들기
sns.barplot(y = 'job', x = 'mean_income', data = bottom10)

plt.show()

# %%
# 막대 그래프 만들기 - 상위 10개 그래프와 축을 맞춰서 비교
sns.barplot(y = 'job', x = 'mean_income', data = bottom10).set(xlim = (0, 900))

plt.show()

# %% [markdown]
# # 중간 데이터 저장

# %%
welfare.to_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv', index = False)

# %%
# 데이터 불러오기
welfare = pd.read_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv')

# %% [markdown]
# ## 6 성별 직업 빈도 - 성별로 어떤 직업이 가장 많을까?

# %% [markdown]
# ### 성별 직업 빈도 분석하기

# %% [markdown]
# #### 1. 성별 직업 빈도표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16670 non-null  int64
#  4   job_code        7529 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
#  9   job             7529 non-null   object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 1.3+ MB

# %%
# 남성 데이터
welfare[welfare['sex'] == 'male']
# Out:
#         sex  birth_year  marital_status  religion  job_code  income  \
# 2      male      1948.0               2         2     942.0   120.0
# 3      male      1942.0               3         1     762.0   200.0
# 5      male      1962.0               1         1     530.0     NaN
# 8      male      1927.0               1         1       NaN     NaN
# 11     male      1956.0               1         2       NaN     NaN
# ...     ...         ...             ...       ...       ...     ...
# 16658  male      1967.0               1         1     874.0     NaN
# 16661  male      1995.0               5         1       NaN     NaN
# 16663  male      2001.0               0         1       NaN     NaN
# 16666  male      1972.0               9         1       NaN     NaN
# 16669  male      1940.0               1         1       NaN     NaN
#
#        region_code   age age_group                   job
# 2                1  68.0       old             경비원 및 검표원
# 3                1  74.0       old                   전기공
# 5                1  54.0    middle  방문 노점 및 통신 판매 관련 종사자
# 8                1  89.0       old                   NaN
# 11               7  60.0       old                   NaN
# ...            ...   ...       ...                   ...
# 16658            5  49.0    middle           물품이동 장비 조작원
# 16661            5  21.0     young                   NaN
# 16663            5  15.0     young                   NaN
# 16666            6  44.0    middle                   NaN
# 16669            5  76.0       old                   NaN
#
# [7580 rows x 10 columns]

# %%
welfare[welfare['sex'] == 'male'].groupby('job', as_index = False).agg(n = ('job', 'count'))
# Out:
#                          job   n
# 0                        간호사   5
# 1             건설 및 광업 단순 종사원  95
# 2              건설 및 채굴 기계운전원  37
# 3          건설 전기 및 생산 관련 관리자  35
# 4                건설관련 기능 종사자  61
# ..                       ...  ..
# 136  화학 고무 및 플라스틱 제품 생산기 조작원  14
# 137           화학공학 기술자 및 시험원   5
# 138        환경 청소 및 경비 관련 관리자  12
# 139           환경공학 기술자 및 시험원   6
# 140              회계 및 경리 사무원  44
#
# [141 rows x 2 columns]

# %%
# 남성 직업 빈도 상위 10개 추출 - 내림 차순 정렬
job_male = welfare[welfare['sex'] == 'male'].dropna(subset = ['job']) \
                                            .groupby('job', as_index = False) \
                                            .agg(n = ('job', 'count')) \
                                            .sort_values('n', ascending = False) \
                                            .head(10)
job_male
# Out:
#                 job    n
# 100        작물재배 종사자  640
# 97          자동차 운전원  251
# 9          경영관련 사무원  213
# 79           영업 종사자  141
# 40        매장 판매 종사자  132
# 114     제조관련 단순 종사원  104
# 121    청소원 및 환경 미화원   97
# 8         경비원 및 검표원   95
# 1    건설 및 광업 단순 종사원   95
# 133          행정 사무원   92

# %%
# 여성 직업 빈도 상위 10개 추출 - 내림 차순 정렬
job_female = welfare[welfare['sex'] == 'female'].dropna(subset = ['job']) \
                                                .groupby('job', as_index = False) \
                                                .agg(n = ('job', 'count')) \
                                                .sort_values('n', ascending = False) \
                                                .head(10)
job_female
# Out:
#                   job    n
# 76           작물재배 종사자  680
# 90       청소원 및 환경 미화원  228
# 31          매장 판매 종사자  221
# 85        제조관련 단순 종사원  185
# 103       회계 및 경리 사무원  176
# 66          음식서비스 종사자  149
# 87          주방장 및 조리사  126
# 0         가사 및 육아 도우미  125
# 67   의료 복지 관련 서비스 종사자  121
# 65        음식관련 단순 종사원  104

# %% [markdown]
# #### 2. 그래프 만들기

# %%
# 남성 직업 빈도 막대 그래프 만들기
sns.barplot(y = 'job', x = 'n', data = job_male)
plt.show()

# %%
# 여성 직업 빈도 막대 그래프 만들기
sns.barplot(y = 'job', x = 'n', data = job_female)
plt.show()

# %%
# 남성 직업 빈도 막대 그래프 만들기
sns.barplot(y = 'job', x = 'n', data = job_male).set(xlim = (0, 800))
plt.show()

# %%
# 여성 직업 빈도 막대 그래프 만들기
sns.barplot(y = 'job', x = 'n', data = job_female).set(xlim = (0, 800))
plt.show()

# %% [markdown]
# ## 7 종교 유무에 따른 이혼율 - 종교가 있으면 이혼을 덜 할까?

# %% [markdown]
# ### 종교 변수 검토 및 전처리하기

# %% [markdown]
# #### 1. 변수 검토하기

# %%
welfare['religion'].dtypes  # 변수 타입 출력
# Out:
# dtype('int64')

# %%
welfare['religion'].value_counts()  # 빈도 구하기
# Out:
# religion
# 2    8619
# 1    8050
# 9       1
# Name: count, dtype: int64

# %% [markdown]
# #### 2. 전처리

# %%
# 이상치 확인
welfare['religion'].value_counts(dropna = False)
# 9 => 코드북 상으로 모름/무응답(미상)
# Out:
# religion
# 2    8619
# 1    8050
# 9       1
# Name: count, dtype: int64

# %%
# 이상치 결측 처리
welfare['religion'] = np.where(welfare['religion'] == 9, np.nan, welfare['religion'])

# %%
# 이상치 확인
welfare['religion'].value_counts(dropna = False)
# Out:
# religion
# 2.0    8619
# 1.0    8050
# NaN       1
# Name: count, dtype: int64

# %%
# 결측치 확인
welfare['religion'].isnull().sum()
# Out:
# 1

# %%
welfare['religion'] = np.where(welfare['religion'].isnull() == True, np.nan,
                               np.where(welfare['religion'] == 1, 'yes', 'no'))

# %%
# 이상치 확인
welfare['religion'].value_counts(dropna = False)
# Out:
# religion
# no     8619
# yes    8050
# nan       1
# Name: count, dtype: int64

# %%
# 결측치 확인
welfare['religion'].isnull().sum()
# Out:
# 0

# %%
#  nan 문자열을 NaN 으로 변환
welfare['religion'] = np.where(welfare['religion'] == 'nan', np.nan, welfare['religion'])

# %%
# 빈도 구하기
welfare['religion'].value_counts(dropna = False)
# Out:
# religion
# no     8619
# yes    8050
# NaN       1
# Name: count, dtype: int64

# %%
# 결측치 확인
welfare['religion'].isnull().sum()
# Out:
# 1

# %%
# 막대 그래프 만들기
sns.countplot(x = 'religion', data = welfare)
plt.show()

# %% [markdown]
# ### 혼인 상태 변수 검토 및 전처리하기

# %% [markdown]
# #### 1. 변수 검토하기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16669 non-null  object
#  4   job_code        7529 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
#  9   job             7529 non-null   object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 1.3+ MB

# %%
welfare['marital_status'].dtypes  # 변수 타입 출력
# Out:
# dtype('int64')

# %%
welfare['marital_status'].value_counts()  # 빈도 구하기
# 0.비해당(18세 미만)
# 1.유배우
# 2.사별
# 3.이혼
# 4.별거
# 5.미혼(18세이상, 미혼모 포함)
# 6.기타(사망 등)
# Out:
# marital_status
# 1    8433
# 0    2861
# 5    2434
# 2    2118
# 3     713
# 4      84
# 6      26
# 9       1
# Name: count, dtype: int64

# %% [markdown]
# #### 2. 파생변수 만들기 - 이혼 여부

# %%
# 변수의 조작적 정의
# 이혼율 = 이혼 / (유배우+이혼)
# 이혼 여부 변수 만들기
welfare['marriage'] = np.where(welfare['marital_status'] == 1, 'marriage',
                               np.where(welfare['marital_status'] == 3, 'divorce', np.nan))

# %%
# 이상치 확인
welfare['marriage'].value_counts(dropna = False)
# Out:
# marriage
# marriage    8433
# nan         7524
# divorce      713
# Name: count, dtype: int64

# %%
# 결측치 확인
welfare['marriage'].isnull().sum()
# Out:
# 0

# %%
#  nan 문자열을 NaN 으로 변환
welfare['marriage'] = np.where(welfare['marriage'] == 'nan', np.nan, welfare['marriage'])

# %%
# 빈도 구하기
welfare['marriage'].value_counts(dropna = False)
# Out:
# marriage
# marriage    8433
# NaN         7524
# divorce      713
# Name: count, dtype: int64

# %%
# 결측치 확인
welfare['marriage'].isnull().sum()
# Out:
# 7524

# %%
# 이혼 여부별 빈도
marriage_count = welfare.groupby('marriage', as_index = False) \
                   .agg(n = ('marriage', 'count'))
# marriage별 분리
# marriage별 빈도 구하기
marriage_count
# Out:
#    marriage     n
# 0   divorce   713
# 1  marriage  8433

# %%
# 막대 그래프 만들기
sns.barplot(x = 'marriage', y = 'n', data = marriage_count)
plt.show()

# %% [markdown]
# ### 종교 유무에 따른 이혼율 분석하기
#
# #### 1. 종교 유무에 따른 이혼율표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16669 non-null  object
#  4   job_code        7529 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
#  9   job             7529 non-null   object
#  10  marriage        9146 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
# 종교와 혼인 변수 그룹으로 모든 열 카운트
welfare.dropna(subset=['religion', 'marriage']).groupby(['religion','marriage']).agg('count')
# Out:
#                    Unnamed: 0   sex  birth_year  marital_status  job_code  \
# religion marriage
# no       divorce          385   385         385             385       247
#          marriage        4218  4218        4218            4218      2778
# yes      divorce          328   328         328             328       172
#          marriage        4214  4214        4214            4214      2529
#
#                    income  region_code   age  age_group   job
# religion marriage
# no       divorce      164          385   385        385   247
#          marriage    1596         4218  4218       4218  2778
# yes      divorce      112          328   328        328   172
#          marriage    1456         4214  4214       4214  2529

# %%
# 하나의 열을 가지고 카운트
welfare.dropna(subset=['religion', 'marriage']).groupby(['religion','marriage'])['marital_status'].agg('count')
# Out:
# religion  marriage
# no        divorce      385
#           marriage    4218
# yes       divorce      328
#           marriage    4214
# Name: marital_status, dtype: int64

# %%
welfare.dropna(subset=['religion', 'marriage']).groupby(['religion','marriage'])['marriage'].agg('count')
# Out:
# religion  marriage
# no        divorce      385
#           marriage    4218
# yes       divorce      328
#           marriage    4214
# Name: marriage, dtype: int64

# %%
# 하나의 열을 가지고 카운트
welfare.dropna(subset=['religion', 'marriage']).groupby(['religion','marriage']).agg(n = ('marriage', 'count'))
# Out:
#                       n
# religion marriage
# no       divorce    385
#          marriage  4218
# yes      divorce    328
#          marriage  4214

# %%
# 더 쉽게 카운트
welfare.dropna(subset=['religion', 'marriage']).groupby(['religion','marriage']).size()
# Out:
# religion  marriage
# no        divorce      385
#           marriage    4218
# yes       divorce      328
#           marriage    4214
# dtype: int64

# %%
# 카운트 열 이름 추가
welfare.dropna(subset=['religion', 'marriage']).groupby(['religion','marriage']).size().reset_index(name='n')
# Out:
#   religion  marriage     n
# 0       no   divorce   385
# 1       no  marriage  4218
# 2      yes   divorce   328
# 3      yes  marriage  4214

# %%
# 한 번에 처리
religion_divorce = welfare.dropna(subset=['religion', 'marriage'])\
                          .groupby(['religion','marriage'])\
                          .size()\
                          .reset_index(name='n')
religion_divorce
# Out:
#   religion  marriage     n
# 0       no   divorce   385
# 1       no  marriage  4218
# 2      yes   divorce   328
# 3      yes  marriage  4214

# %%
# 이혼율 계산하기 위한 부분합 만들기
religion_divorce['total'] = religion_divorce.groupby('religion')['n'].transform('sum')
religion_divorce
# Out:
#   religion  marriage     n  total
# 0       no   divorce   385   4603
# 1       no  marriage  4218   4603
# 2      yes   divorce   328   4542
# 3      yes  marriage  4214   4542

# %%
# 이혼율 - 백분율 만들기
religion_divorce['pct'] = (religion_divorce['n']/religion_divorce['total']*100).round(2)
religion_divorce
# Out:
#   religion  marriage     n  total    pct
# 0       no   divorce   385   4603   8.36
# 1       no  marriage  4218   4603  91.64
# 2      yes   divorce   328   4542   7.22
# 3      yes  marriage  4214   4542  92.78

# %%
# 더 쉽게 카운트
welfare.dropna(subset=['religion', 'marriage']).groupby(['religion'])['marriage'].value_counts()
# Out:
# religion  marriage
# no        marriage    4218
#           divorce      385
# yes       marriage    4214
#           divorce      328
# Name: count, dtype: int64

# %%
welfare.dropna(subset=['religion', 'marriage']).groupby(['religion'])['marriage'].value_counts(normalize = True)
# Out:
# religion  marriage
# no        marriage    0.916359
#           divorce     0.083641
# yes       marriage    0.927785
#           divorce     0.072215
# Name: proportion, dtype: float64

# %%
welfare.dropna(subset = ['religion', 'marriage']).groupby('religion', as_index = False)['marriage'].value_counts(normalize = True)
# Out:
#   religion  marriage  proportion
# 0       no  marriage    0.916359
# 1       no   divorce    0.083641
# 2      yes  marriage    0.927785
# 3      yes   divorce    0.072215

# %%
# 한 번에 처리
religion_div = welfare.dropna(subset = ['religion', 'marriage']) \
                      .groupby('religion', as_index = False) \
                      ['marriage'] \
                      .value_counts(normalize = True)
religion_div
# Out:
#   religion  marriage  proportion
# 0       no  marriage    0.916359
# 1       no   divorce    0.083641
# 2      yes  marriage    0.927785
# 3      yes   divorce    0.072215

# %% [markdown]
# #### 2. 그래프 만들기

# %%
# 이혼율 데이터
religion_div[religion_div['marriage'] == 'divorce']
# Out:
#   religion marriage  proportion
# 1       no  divorce    0.083641
# 3      yes  divorce    0.072215

# %%
religion_div = religion_div[religion_div['marriage'] == 'divorce'] \
               .assign(proportion = religion_div['proportion'] * 100) \
               .round(2)
religion_div
# Out:
#   religion marriage  proportion
# 1       no  divorce        8.36
# 3      yes  divorce        7.22

# %%
religion_div.iloc[0,2] - religion_div.iloc[1,2]
# Out:
# 1.1399999999999997

# %%
# 막대 그래프 만들기
sns.barplot(x = "religion", y = 'proportion', data = religion_div)
plt.show()

# %% [markdown]
# ### 연령대 및 종교 유무에 따른 이혼율 분석하기

# %% [markdown]
# #### 1. 연령대별 이혼율표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16669 non-null  object
#  4   job_code        7529 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
#  9   job             7529 non-null   object
#  10  marriage        9146 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
# 연령대 및 이혼 여부별 빈도
welfare.dropna(subset = ['age_group', 'religion']) \
       .groupby('age_group', as_index = False) \
       ['marriage'] \
       .value_counts()
# Out:
#   age_group  marriage  count
# 0    middle  marriage   4481
# 1    middle   divorce    438
# 2       old  marriage   3893
# 3       old   divorce    273
# 4     young  marriage     58
# 5     young   divorce      2

# %%
# 비율 계산
age_group_div = welfare.dropna(subset = ['age_group', 'religion']) \
                 .groupby('age_group', as_index = False) \
                 ['marriage'] \
                 .value_counts(normalize = True)
age_group_div
# Out:
#   age_group  marriage  proportion
# 0    middle  marriage    0.910958
# 1    middle   divorce    0.089042
# 2       old  marriage    0.934470
# 3       old   divorce    0.065530
# 4     young  marriage    0.966667
# 5     young   divorce    0.033333

# %% [markdown]
# #### 2. 연령대별 이혼율 그래프 만들기

# %%
# 이혼율 데이터 & 젊은 층이 아닌 연령대 데이터
age_group_div[(age_group_div['marriage'] == 'divorce') & (age_group_div['age_group'] != 'young')]
# Out:
#   age_group marriage  proportion
# 1    middle  divorce    0.089042
# 3       old  divorce    0.065530

# %%
age_group_div = age_group_div[(age_group_div['marriage'] == 'divorce') & (age_group_div['age_group'] != 'young')] \
                             .assign(proportion = age_group_div['proportion'] * 100) \
                             .round(2)
age_group_div
# Out:
#   age_group marriage  proportion
# 1    middle  divorce        8.90
# 3       old  divorce        6.55

# %%
round(age_group_div.iloc[0,2] - age_group_div.iloc[1,2], ndigits = 2)
# Out:
# 2.35

# %%
# 막대 그래프 만들기
sns.barplot(x = "age_group", y = 'proportion', data = age_group_div)
plt.show()

# %% [markdown]
# #### 3. 연령대 및 종교 유무에 따른 이혼율표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16669 non-null  object
#  4   job_code        7529 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
#  9   job             7529 non-null   object
#  10  marriage        9146 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
# 젊은 층이 아닌 연령대 데이터
welfare[welfare['age_group'] != 'young']
# Out:
#           sex  birth_year  marital_status religion  job_code  income  \
# 0      female      1936.0               2       no       NaN     NaN
# 1      female      1945.0               2       no       NaN     NaN
# 2        male      1948.0               2       no     942.0   120.0
# 3        male      1942.0               3      yes     762.0   200.0
# 4      female      1923.0               2      yes       NaN     NaN
# ...       ...         ...             ...      ...       ...     ...
# 16665  female         NaN               5      yes       NaN     NaN
# 16666    male      1972.0               9      yes       NaN     NaN
# 16667  female      1969.0               1      NaN       NaN     NaN
# 16668  female      1960.0               3       no       NaN     NaN
# 16669    male      1940.0               1      yes       NaN     NaN
#
#        region_code   age age_group        job  marriage
# 0                1  80.0       old        NaN       NaN
# 1                1  71.0       old        NaN       NaN
# 2                1  68.0       old  경비원 및 검표원       NaN
# 3                1  74.0       old        전기공   divorce
# 4                1  93.0       old        NaN       NaN
# ...            ...   ...       ...        ...       ...
# 16665            6   NaN       NaN        NaN       NaN
# 16666            6  44.0    middle        NaN       NaN
# 16667            2  47.0    middle        NaN  marriage
# 16668            6  56.0    middle        NaN   divorce
# 16669            5  76.0       old        NaN  marriage
#
# [12336 rows x 11 columns]

# %%
# 연령대, 종교 유무, 이혼 여부별 비율
age_group_rel_div = welfare[welfare['age_group'] != 'young'] \
                      .dropna(subset = ['age_group', 'religion', 'marriage']) \
                      .groupby(['age_group', 'religion'], as_index = False) \
                       ['marriage'] \
                       .value_counts(normalize = True)
age_group_rel_div
# Out:
#   age_group religion  marriage  proportion
# 0    middle       no  marriage    0.902685
# 1    middle       no   divorce    0.097315
# 2    middle      yes  marriage    0.920876
# 3    middle      yes   divorce    0.079124
# 4       old       no  marriage    0.934713
# 5       old       no   divorce    0.065287
# 6       old      yes  marriage    0.934268
# 7       old      yes   divorce    0.065732

# %% [markdown]
# #### 4. 연령대 및 종교 유무에 따른 이혼율 그래프 만들기

# %%
# 이혼율 데이터
age_group_rel_div[age_group_rel_div['marriage'] == 'divorce']
# Out:
#   age_group religion marriage  proportion
# 1    middle       no  divorce    0.097315
# 3    middle      yes  divorce    0.079124
# 5       old       no  divorce    0.065287
# 7       old      yes  divorce    0.065732

# %%
age_group_rel_div = age_group_rel_div[age_group_rel_div['marriage'] == 'divorce'] \
                    .assign(proportion = age_group_rel_div['proportion'] * 100) \
                    .round(2)
age_group_rel_div
# Out:
#   age_group religion marriage  proportion
# 1    middle       no  divorce        9.73
# 3    middle      yes  divorce        7.91
# 5       old       no  divorce        6.53
# 7       old      yes  divorce        6.57

# %%
print(round(age_group_rel_div.iloc[0,3] - age_group_rel_div.iloc[1,3], 2))
print(round(age_group_rel_div.iloc[3,3] - age_group_rel_div.iloc[2,3], 2))
# Out:
# 1.82
# 0.04

# %%
# 막대 그래프 만들기
sns.barplot(x = 'age_group', y = 'proportion', hue = 'religion', data = age_group_rel_div)
plt.show()

# %% [markdown]
# # 중간 데이터 저장

# %%
welfare.to_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv', index = False)

# %%
# 데이터 불러오기
welfare = pd.read_csv('/content/drive/MyDrive/lsda02/data/welfare_2015_0408.csv')

# %% [markdown]
# ## 8 지역별 연령대 비율 - 어느 지역에 노년층이 많을까?
#
# ### 지역 변수 검토 및 전처리하기
#
# #### 1. 변수 검토하기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16669 non-null  object
#  4   job_code        7529 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
#  9   job             7529 non-null   object
#  10  marriage        9146 non-null   object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
welfare['region_code'].dtypes  # 변수 타입 출력
# Out:
# dtype('int64')

# %%
welfare['region_code'].value_counts()  # 빈도 구하기
# Out:
# region_code
# 2    3712
# 7    2922
# 3    2785
# 1    2487
# 4    2036
# 5    1468
# 6    1260
# Name: count, dtype: int64

# %% [markdown]
# #### 2. 전처리

# %%
# 이상치 확인
welfare['region_code'].value_counts(dropna = False)
# 9 => 코드북 상으로 모름/무응답(미상) => 없음
# Out:
# region_code
# 2    3712
# 7    2922
# 3    2785
# 1    2487
# 4    2036
# 5    1468
# 6    1260
# Name: count, dtype: int64

# %%
# 지역 코드 목록 만들기
region_list = pd.DataFrame({'region_code' : [1, 2, 3, 4, 5, 6, 7],
                            'region'      : ['서울',
                                             '수도권(인천/경기)',
                                             '부산/경남/울산',
                                             '대구/경북',
                                             '대전/충남',
                                             '강원/충북',
                                             '광주/전남/전북/제주도']})
region_list
# Out:
#    region_code        region
# 0            1            서울
# 1            2    수도권(인천/경기)
# 2            3      부산/경남/울산
# 3            4         대구/경북
# 4            5         대전/충남
# 5            6         강원/충북
# 6            7  광주/전남/전북/제주도

# %%
# 지역명 변수 추가
welfare = welfare.merge(region_list, how = 'left', on = 'region_code')
welfare.head()
# Out:
#       sex  birth_year  marital_status religion  job_code  income  region_code  \
# 0  female      1936.0               2       no       NaN     NaN            1
# 1  female      1945.0               2       no       NaN     NaN            1
# 2    male      1948.0               2       no     942.0   120.0            1
# 3    male      1942.0               3      yes     762.0   200.0            1
# 4  female      1923.0               2      yes       NaN     NaN            1
#
#     age age_group        job marriage region
# 0  80.0       old        NaN      NaN     서울
# 1  71.0       old        NaN      NaN     서울
# 2  68.0       old  경비원 및 검표원      NaN     서울
# 3  74.0       old        전기공  divorce     서울
# 4  93.0       old        NaN      NaN     서울

# %%
# 데이터 확인
welfare[['region_code', 'region']]
# Out:
#        region_code      region
# 0                1          서울
# 1                1          서울
# 2                1          서울
# 3                1          서울
# 4                1          서울
# ...            ...         ...
# 16665            6       강원/충북
# 16666            6       강원/충북
# 16667            2  수도권(인천/경기)
# 16668            6       강원/충북
# 16669            5       대전/충남
#
# [16670 rows x 2 columns]

# %% [markdown]
# ### 지역별 연령대 비율 분석하기

# %% [markdown]
# #### 1. 지역별 연령대 비율표 만들기

# %%
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16670 entries, 0 to 16669
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             16669 non-null  object
#  1   birth_year      16669 non-null  float64
#  2   marital_status  16670 non-null  int64
#  3   religion        16669 non-null  object
#  4   job_code        7529 non-null   float64
#  5   income          4620 non-null   float64
#  6   region_code     16670 non-null  int64
#  7   age             16669 non-null  float64
#  8   age_group       16669 non-null  object
#  9   job             7529 non-null   object
#  10  marriage        9146 non-null   object
#  11  region          16670 non-null  object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 1.5+ MB

# %%
region_age_group = welfare.dropna(subset = ['age_group']) \
                     .groupby('region', as_index = False) \
                     ['age_group'] \
                     .value_counts(normalize = True)
region_age_group
# Out:
#           region age_group  proportion
# 0          강원/충북       old    0.440826
# 1          강원/충북    middle    0.332804
# 2          강원/충북     young    0.226370
# 3   광주/전남/전북/제주도       old    0.421971
# 4   광주/전남/전북/제주도    middle    0.324093
# 5   광주/전남/전북/제주도     young    0.253936
# 6          대구/경북       old    0.455796
# 7          대구/경북    middle    0.312868
# 8          대구/경북     young    0.231336
# 9          대전/충남    middle    0.373297
# 10         대전/충남       old    0.359673
# 11         대전/충남     young    0.267030
# 12      부산/경남/울산       old    0.403591
# 13      부산/경남/울산    middle    0.353321
# 14      부산/경남/울산     young    0.243088
# 15            서울    middle    0.414154
# 16            서울       old    0.324085
# 17            서울     young    0.261761
# 18    수도권(인천/경기)    middle    0.400593
# 19    수도권(인천/경기)     young    0.300647
# 20    수도권(인천/경기)       old    0.298761

# %% [markdown]
# #### 2. 그래프 만들기

# %%
region_age_group = region_age_group.assign(proportion = region_age_group['proportion'] * 100) \
                                   .round(2)
region_age_group
# Out:
#           region age_group  proportion
# 0          강원/충북       old       44.08
# 1          강원/충북    middle       33.28
# 2          강원/충북     young       22.64
# 3   광주/전남/전북/제주도       old       42.20
# 4   광주/전남/전북/제주도    middle       32.41
# 5   광주/전남/전북/제주도     young       25.39
# 6          대구/경북       old       45.58
# 7          대구/경북    middle       31.29
# 8          대구/경북     young       23.13
# 9          대전/충남    middle       37.33
# 10         대전/충남       old       35.97
# 11         대전/충남     young       26.70
# 12      부산/경남/울산       old       40.36
# 13      부산/경남/울산    middle       35.33
# 14      부산/경남/울산     young       24.31
# 15            서울    middle       41.42
# 16            서울       old       32.41
# 17            서울     young       26.18
# 18    수도권(인천/경기)    middle       40.06
# 19    수도권(인천/경기)     young       30.06
# 20    수도권(인천/경기)       old       29.88

# %%
# 막대 그래프 만들기
sns.barplot(y = 'region', x = 'proportion', hue = 'age_group', data = region_age_group).set(xlim = (0,60))
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# #### 3. 누적 비율 막대 그래프 만들기
#
# **(1) 피벗하기**

# %%
region_age_group
# Out:
#           region age_group  proportion
# 0          강원/충북       old       44.08
# 1          강원/충북    middle       33.28
# 2          강원/충북     young       22.64
# 3   광주/전남/전북/제주도       old       42.20
# 4   광주/전남/전북/제주도    middle       32.41
# 5   광주/전남/전북/제주도     young       25.39
# 6          대구/경북       old       45.58
# 7          대구/경북    middle       31.29
# 8          대구/경북     young       23.13
# 9          대전/충남    middle       37.33
# 10         대전/충남       old       35.97
# 11         대전/충남     young       26.70
# 12      부산/경남/울산       old       40.36
# 13      부산/경남/울산    middle       35.33
# 14      부산/경남/울산     young       24.31
# 15            서울    middle       41.42
# 16            서울       old       32.41
# 17            서울     young       26.18
# 18    수도권(인천/경기)    middle       40.06
# 19    수도권(인천/경기)     young       30.06
# 20    수도권(인천/경기)       old       29.88

# %%
# 피벗
pivot_region_age_group = region_age_group[['region', 'age_group', 'proportion']] \
                          .pivot(index   = 'region',
                          columns = 'age_group',
                          values  = 'proportion')
pivot_region_age_group
# Out:
# age_group     middle    old  young
# region
# 강원/충북          33.28  44.08  22.64
# 광주/전남/전북/제주도   32.41  42.20  25.39
# 대구/경북          31.29  45.58  23.13
# 대전/충남          37.33  35.97  26.70
# 부산/경남/울산       35.33  40.36  24.31
# 서울             41.42  32.41  26.18
# 수도권(인천/경기)     40.06  29.88  30.06

# %% [markdown]
# **(2) 그래프 만들기**

# %%
# 가로 막대 그래프 만들기
pivot_region_age_group.plot.barh(stacked = True)
plt.legend(bbox_to_anchor=(1.0, 1.0)) # 우상
plt.show()

# %% [markdown]
# **(3) 막대 정렬하기**

# %%
pivot_region_age_group.sort_values('old')
# Out:
# age_group     middle    old  young
# region
# 수도권(인천/경기)     40.06  29.88  30.06
# 서울             41.42  32.41  26.18
# 대전/충남          37.33  35.97  26.70
# 부산/경남/울산       35.33  40.36  24.31
# 광주/전남/전북/제주도   32.41  42.20  25.39
# 강원/충북          33.28  44.08  22.64
# 대구/경북          31.29  45.58  23.13

# %%
# 노년층 비율 기준 오름 차순 정렬, 변수 순서 바꾸기
reorder_pivot_region_age_group = pivot_region_age_group.sort_values('old')[['young', 'middle', 'old']]
reorder_pivot_region_age_group
# Out:
# age_group     young  middle    old
# region
# 수도권(인천/경기)    30.06   40.06  29.88
# 서울            26.18   41.42  32.41
# 대전/충남         26.70   37.33  35.97
# 부산/경남/울산      24.31   35.33  40.36
# 광주/전남/전북/제주도  25.39   32.41  42.20
# 강원/충북         22.64   33.28  44.08
# 대구/경북         23.13   31.29  45.58

# %%
# 누적 가로 막대 그래프 만들기
reorder_pivot_region_age_group.plot.barh(stacked = True) # 오름 차순의 반대 = 축 전환
# reorder_pivot_region_age_group.plot.bar(stacked = True) # 오름 차순
plt.legend(bbox_to_anchor=(1.0, 1.0)) # 우상
plt.show()

# %%
# bbox_to_anchor 위치 테스트
bbox_to_anchor_list = [1.0,0.5,0]
for i in bbox_to_anchor_list:
  for j in bbox_to_anchor_list:
    print(i,j)
    pivot_region_age_group.plot.barh(stacked = True)
    plt.legend(bbox_to_anchor=(i, j))
    plt.show()
# Out:
# 1.0 1.0
# 1.0 0.5
# 1.0 0
# 0.5 1.0
# 0.5 0.5
# 0.5 0
# 0 1.0
# 0 0.5
# 0 0
